# %%
from omegaconf import OmegaConf
from sklearn.linear_model import LogisticRegression
from hydra.utils import instantiate
import pandas as pd

# %%
conf = OmegaConf.create({"k" : "v", "list" : [1, {"a": "1", "b": "2", 3: "c"}]})
print(OmegaConf.to_yaml(conf))
# Out:
# k: v
# list:
# - 1
# - a: '1'
#   b: '2'
#   3: c

# %%
conf
# Out:
# {'k': 'v', 'list': [1, {'a': '1', 'b': '2', 3: 'c'}]}

# %%
conf.k
# Out:
# 'v'

# %%
model = LogisticRegression()
model_step = OmegaConf.create({"_target_": "sklearn.linear_model.LogisticRegression", "C": 0.1})
cfg = OmegaConf.create({
    "model": {"m": model_step},
})

# %%
type(cfg.model.m)
# Out:
# omegaconf.dictconfig.DictConfig

# %%
instantiate(cfg.model.m)
# Out:
# LogisticRegression(C=0.1)

# %%
def test():
 
    c = []
    for i in range(10000000):
        c.append(i*i*i)
    return c

test_dict = {

    "a": test
}

test_dict["a"]

second_dict = {

    "a": test()
}

# %%
second_dict.__sizeof__()
second_dict['a'].__sizeof__()
# Out:
# 89095144

# %%
test_dict.__sizeof__()
test_dict['a'].__sizeof__()
# Out:
# 136

# %%
class mydict(dict):
    def __getitem__(self, key):
        return super().__getitem__(key)()

# %%
for i in mydict(test_dict):
    print(i)
# Out:
# a

# %%
from model_forge.data.dataset import Dataset
data = pd.DataFrame({
        'feature1': [1, 2, 3, 4, 5],
        'feature2': [6, 7, 8, 9, 10],
        'target': [0, 0, 1, 1, 1]
    })
Dataset(data=data, target_column='target')
# Out:
#  2024-04-12 11:21:36,858 -  INFO  	: my_logger.custom_logger - Logger is set up.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 7
#       1 from model_forge.data.dataset import Dataset
#       2 data = pd.DataFrame({
#       3         'feature1': [1, 2, 3, 4, 5],
#       4         'feature2': [6, 7, 8, 9, 10],
#       5         'target': [0, 0, 1, 1, 1]
#       6     })
# ----> 7 Dataset(data=data, target_column='target')
#
# File c:\Bewaar\Data_Science\model-forge\model_forge\data\dataset.py:63, in Dataset.__init__(self, data, data_splitter, target_column, name, splits_columns)
#      61 self._is_data_splitted = False
#      62 self.data = data
# ---> 63 super().__init__( self._split_data() )
#
# File c:\Bewaar\Data_Science\model-forge\model_forge\data\dataset.py:124, in Dataset._split_data(self)
# ...
